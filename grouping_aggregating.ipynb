# %%
import pandas as pd

# %%
df=pd.read_csv("data2/survey_results_public.csv",index_col="Respondent")
schema_df=pd.read_csv("data2/survey_results_schema.csv",index_col="Column")

# %%
pd.set_option("display.max_columns",85)
pd.set_option("display.max_rows",85)

# %%
df

# %%
df["ConvertedComp"].head(15)
# Out:
# Respondent
# 1          NaN
# 2          NaN
# 3       8820.0
# 4      61000.0
# 5          NaN
# 6     366420.0
# 7          NaN
# 8          NaN
# 9      95179.0
# 10     13293.0
# 11         NaN
# 12         NaN
# 13     90000.0
# 14     57060.0
# 15         NaN
# Name: ConvertedComp, dtype: float64

# %%
df["ConvertedComp"].median()

# %%
df.median()

# %%
df.describe()
# Out:
#           CompTotal  ConvertedComp   WorkWeekHrs    CodeRevHrs           Age
# count  5.594500e+04   5.582300e+04  64503.000000  49790.000000  79210.000000
# mean   5.519014e+11   1.271107e+05     42.127197      5.084308     30.336699
# std    7.331926e+13   2.841523e+05     37.287610      5.513931      9.178390
# min    0.000000e+00   0.000000e+00      1.000000      0.000000      1.000000
# 25%    2.000000e+04   2.577750e+04     40.000000      2.000000     24.000000
# 50%    6.200000e+04   5.728700e+04     40.000000      4.000000     29.000000
# 75%    1.200000e+05   1.000000e+05     44.750000      6.000000     35.000000
# max    1.000000e+16   2.000000e+06   4850.000000     99.000000     99.000000

# %%
df["ConvertedComp"].count()
# Out:
# 55823

# %%
df["Hobbyist"].value_counts()

# %%
df["SocialMedia"]
# Out:
# Respondent
# 1          Twitter
# 2        Instagram
# 3           Reddit
# 4           Reddit
# 5         Facebook
#            ...
# 88377      YouTube
# 88601          NaN
# 88802          NaN
# 88816          NaN
# 88863     WhatsApp
# Name: SocialMedia, Length: 88883, dtype: object

# %%
schema_df.loc["SocialMedia"]

# %%
df["SocialMedia"].value_counts(normalize=True)

# %%
df["Country"].value_counts()
# Out:
# United States        20949
# India                 9061
# Germany               5866
# United Kingdom        5737
# Canada                3395
#                      ...
# Tonga                    1
# Timor-Leste              1
# North Korea              1
# Brunei Darussalam        1
# Chad                     1
# Name: Country, Length: 179, dtype: int64

# %%
# country_grp=df.groupby("Country")["SocialMedia"].value_counts()
country_grp=df.groupby(["Country"])

country_grp

# %%
country_grp.get_group("United States")

# %%
# filt=df["Country"].str.contains("United States",na=False) #or
filt2=df["Country"]=="Bangladesh"
df.loc[filt2,"SocialMedia"].value_counts()

# %%
country_grp["SocialMedia"] .value_counts(normalize=True).loc["Bangladesh"]
# Out:
# SocialMedia
# Facebook                    0.537801
# YouTube                     0.235395
# LinkedIn                    0.106529
# Twitter                     0.032646
# I don't use social media    0.029210
# WhatsApp                    0.024055
# Reddit                      0.015464
# Instagram                   0.013746
# Snapchat                    0.003436
# VK ВКонта́кте               0.001718
# Name: SocialMedia, dtype: float64

# %%
# country_grp["ConvertedComp"].median()
country_grp["ConvertedComp"].median().loc["Bangladesh"]

# %%
country_grp["ConvertedComp"].agg(["median","mean"])

# %%
# filt=df["LanguageWorkedWith"]=="Python"

# df.loc[filt,"Country"].value_counts()

filt=df["Country"]=="India"
df.loc[filt,"LanguageWorkedWith"].str.contains("Python").sum()
# Out:
# 3105

# %%
country_grp["LanguageWorkedWith"].apply(lambda x:x.str.contains("Python").sum())

# %%
country_grp["LanguageWorkedWith"].apply(lambda x:x.str.contains("Python").sum()).loc["Bangladesh"]

# %%
country_respondents=df["Country"].value_counts()
country_respondents
# Out:
# United States        20949
# India                 9061
# Germany               5866
# United Kingdom        5737
# Canada                3395
#                      ...
# Tonga                    1
# Timor-Leste              1
# North Korea              1
# Brunei Darussalam        1
# Chad                     1
# Name: Country, Length: 179, dtype: int64

# %%
country_uses_python=country_grp["LanguageWorkedWith"].apply(lambda x:x.str.contains("Python").sum())
country_uses_python
# Out:
# Country
# Afghanistan                              8
# Albania                                 23
# Algeria                                 40
# Andorra                                  0
# Angola                                   2
#                                         ..
# Venezuela, Bolivarian Republic of...    28
# Viet Nam                                78
# Yemen                                    3
# Zambia                                   4
# Zimbabwe                                14
# Name: LanguageWorkedWith, Length: 179, dtype: int64

# %%
python_df=pd.concat([country_respondents,country_uses_python],axis="columns",sort=False)
python_df
# Out:
#                    Country  LanguageWorkedWith
# United States        20949               10083
# India                 9061                3105
# Germany               5866                2451
# United Kingdom        5737                2384
# Canada                3395                1558
# ...                    ...                 ...
# Tonga                    1                   0
# Timor-Leste              1                   1
# North Korea              1                   0
# Brunei Darussalam        1                   0
# Chad                     1                   0
#
# [179 rows x 2 columns]

# %%
python_df.rename(columns={"Country":"NumRespondents","LanguageWorkedWith":"NumKnowsPython"},inplace=True)
python_df
# Out:
#                    NumRespondents  NumKnowsPython
# United States               20949           10083
# India                        9061            3105
# Germany                      5866            2451
# United Kingdom               5737            2384
# Canada                       3395            1558
# ...                           ...             ...
# Tonga                           1               0
# Timor-Leste                     1               1
# North Korea                     1               0
# Brunei Darussalam               1               0
# Chad                            1               0
#
# [179 rows x 2 columns]

# %%
python_df["PctKnowsPython"]=(python_df["NumKnowsPython"]/python_df["NumRespondents"])
python_df
# Out:
#                    NumRespondents  NumKnowsPython  PctKnowsPython
# United States               20949           10083        0.481312
# India                        9061            3105        0.342677
# Germany                      5866            2451        0.417832
# United Kingdom               5737            2384        0.415548
# Canada                       3395            1558        0.458910
# ...                           ...             ...             ...
# Tonga                           1               0        0.000000
# Timor-Leste                     1               1        1.000000
# North Korea                     1               0        0.000000
# Brunei Darussalam               1               0        0.000000
# Chad                            1               0        0.000000
#
# [179 rows x 3 columns]

# %%
python_df.sort_values(by="PctKnowsPython",ascending=False,inplace=True)
python_df.head(50)
# Out:
#                                   NumRespondents  NumKnowsPython  \
# Sao Tome and Principe                          1               1
# Timor-Leste                                    1               1
# Dominica                                       1               1
# Niger                                          1               1
# Turkmenistan                                   7               6
# Mauritania                                     7               5
# Guinea                                         3               2
# Bahamas                                        3               2
# Guyana                                         3               2
# Uganda                                        72              47
# Iceland                                       49              30
# Haiti                                          5               3
# Benin                                          5               3
# ...

# %%
import pandas as pd
people={
    "first":["Corey","John","Jane"],
    "last":["Schafer","Doe","Doe"],
    "email":["Schafer@gmail.com","jane@gmail.com","john@gmail.com"]
}
df=pd.DataFrame(people)
df
# Out:
#    first     last              email
# 0  Corey  Schafer  Schafer@gmail.com
# 1   John      Doe     jane@gmail.com
# 2   Jane      Doe     john@gmail.com

# %%
df
# Out:
#    first     last              email
# 0  Corey  Schafer  Schafer@gmail.com
# 1   John      Doe     jane@gmail.com
# 2   Jane      Doe     john@gmail.com

# %%
df.sort_values(by="last")
# Out:
#    first     last              email
# 1   John      Doe     jane@gmail.com
# 2   Jane      Doe     john@gmail.com
# 0  Corey  Schafer  Schafer@gmail.com

# %%
df.sort_values(by=["last","first"],ascending=[True,False])
df
# Out:
#    first     last              email
# 0  Corey  Schafer  Schafer@gmail.com
# 1   John      Doe     jane@gmail.com
# 2   Jane      Doe     john@gmail.com

# %%
df.sort_values(by=["last","first"],ascending=[False,True])
df
# Out:
#    first     last              email
# 0  Corey  Schafer  Schafer@gmail.com
# 1   John      Doe     jane@gmail.com
# 2   Jane      Doe     john@gmail.com

# %%
df.sort_index()
# Out:
#    first     last              email
# 0  Corey  Schafer  Schafer@gmail.com
# 1   John      Doe     jane@gmail.com
# 2   Jane      Doe     john@gmail.com

# %%
df["last"].sort_values()
# Out:
# 1        Doe
# 2        Doe
# 0    Schafer
# Name: last, dtype: object

# %%
schema_df=pd.read_csv("data2/survey_results_public.csv")
pd.set_option("display.max_columns",79)
schema_df
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 0               1             I am a student who is learning to code      Yes
# 1               2             I am a student who is learning to code       No
# 2               3  I am not primarily a developer, but I write co...      Yes
# 3               4                     I am a developer by profession       No
# 4               5                     I am a developer by profession      Yes
# ...           ...                                                ...      ...
# 88878       88377                                                NaN      Yes
# 88879       88601                                                NaN       No
# 88880       88802                                                NaN       No
# 88881       88816                                                NaN       No
# 88882       88863                                                NaN      Yes
#
# ...

# %%
schema_df.sort_values(by="Country")
# schema_df["Country"].head(50)
schema_df[["Country","ConvertedComp"]].head(50)
# Out:
#            Country  ConvertedComp
# 39018  Afghanistan        19152.0
# 86551  Afghanistan            NaN
# 58390  Afghanistan            NaN
# 73920  Afghanistan            NaN
# 28877  Afghanistan            NaN
# 51525  Afghanistan            NaN
# 45562  Afghanistan            NaN
# 46807  Afghanistan            NaN
# 44123  Afghanistan            NaN
# 22327  Afghanistan         7980.0
# 8112   Afghanistan         1596.0
# 80423  Afghanistan            NaN
# 59184  Afghanistan            NaN
# 60185  Afghanistan            NaN
# 37571  Afghanistan            NaN
# 29560  Afghanistan         1116.0
# 42832  Afghanistan            NaN
# 12253  Afghanistan            NaN
# 58082  Afghanistan        17556.0
# 50172  Afghanistan       153216.0
# 7323   Afghanistan            NaN
# 7056   Afghanistan        14364.0
# 61770  Afghanistan            NaN
# 86394  Afghanistan            NaN
# 85293  Afghanistan            NaN
# 85185  Afghanistan            NaN
# ...

# %%
schema_df.sort_values(by=["Country","ConvertedComp"],ascending=[True,False])
schema_df[["Country","ConvertedComp"]].head(50)
# Out:
#                                 Country  ConvertedComp
# 77992                             India            0.0
# 1774   Other Country (Not Listed Above)            0.0
# 15258                       South Korea            0.0
# 65271                             India            0.0
# 73680                             India            0.0
# 51076                           Ecuador            0.0
# 11136                             India            0.0
# 64761                             India            0.0
# 38814                            Canada            0.0
# 5609                               Iran            0.0
# 12688                             India            0.0
# 17935                             India            0.0
# 10211                           Ukraine            0.0
# 59902                             India            0.0
# 55011                           Germany            0.0
# 41956                             India            0.0
# ...
